# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent
import re
from bs4 import BeautifulSoup

import pandas as pd
import numpy as np

# %%
opts = Options()
ua = UserAgent()
user_agent = ua.random

opts.add_argument("user-agent=" + user_agent)
driver = webdriver.Chrome('/home/bryce/Downloads/chromedriver', options=opts)
apt_url = "https://www.apartments.com/5-murphy-ct-charleston-sc/mhkz90k/"
#apt_url = "https://www.apartments.com/2030-wildts-battery-blvd-johns-island-sc-unit-33847624/ks54vsb/"
driver.get(apt_url)
driver.maximize_window()
# Out:
# /tmp/ipykernel_21120/188480011.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/home/bryce/Downloads/chromedriver', options=opts)

# %%
soup = BeautifulSoup(driver.page_source)

description_section = soup.find("section", class_="descriptionSection")

# %%
# For each apartment, we will write its info in this format:
PRINT_STR = "{addr};; ${rent};; {beds} bd;; {baths} ba;; {sqft} sq ft\n"
PRICING_GRID_ITEM = "pricingGridItem"
SCREEN_READER_ONLY = "screenReaderOnly"

def get_address_string(soup):
    address_divs = soup.find_all("div", class_="propertyAddressContainer")
    if (len(address_divs) == 0) :
        print("COULD NOT FIND ADDRESS")
        return "UNKNOWN ADDRESS"
    addr_string = " ".join(address_divs[0].text.split())

    # Some properties have a property name like "The Meadows". In these properties, the addr_string contains the street address.
    # For single houses and such, the property name is the street address, and the addr_string will be missing it.
    property_name_split = soup.find("h1", class_="propertyName").text.split()
    if len(property_name_split) == 0:
        print("WARNING: no property name found.")
        return addr_string
    # If the property name starts with a number, we'll assume it's an address.
    first_word = property_name_split[0]
    NUMBERS_DASH_OR_DOT = r'(\d+)(?:[\-\.]\d+)?'
    m = re.match(NUMBERS_DASH_OR_DOT, first_word)
    if m:
        property_name_split[0] = m.groups()[0]  # replace "43-45 Meeting St" with "43 Meeting St" for better latlng lookup
        street_address = " ".join(property_name_split)
        addr_string = street_address + ", " + addr_string

    return addr_string

def is_single_unit_listing(soup):
    # Does this page have a div of class "pricingGridItem"? If so, return false. If not, true
    pricing_grid_items = soup.find_all("div", class_=PRICING_GRID_ITEM)
    if (pricing_grid_items):
        return False
    return True

def save_info_from_single_unit_listing(soup, outfile):
    address = get_address_string(soup)
    rent_details = soup.find_all("p", class_="rentInfoDetail")
    printstr = address + ";; " + ";; ".join(map(lambda rd : rd.string if rd.string else " ", rent_details)) + "\n"
    outfile.write(printstr)

""" Some multi-unit listings have an exact price row for every
unit that's available. Otherse just have a price range for each floor plan.
This function handles the latter case.
We'll just save the price range as the price. When doing data analysis, we can
decide how to handle these cases."""
def save_less_precise_info_from_multi_unit_listing(soup, address, outfile):
    pricing_grid_items = soup.find_all("div", class_=PRICING_GRID_ITEM)
    for item in pricing_grid_items:
        classes = item.parent["class"]
        if 'active' not in classes:
            continue
        rent_range = item.find("span", class_="rentLabel").text.strip()
        ### print("rent range: ", rent_range)
        # The first detailsTextWrapper has the bed, bath, sq ft info
        other_info = item.find(class_="detailsTextWrapper").text
        other_info = other_info.replace("bed", "bd").replace("bath", "ba")
        formatted_info = ";; ".join([w.strip() for w in other_info.split(",")])
        println = "{address};; {rent_range};; {bd_ba_sqft}\n".format(address=address, rent_range=rent_range, bd_ba_sqft=formatted_info)
        outfile.write(println)


def save_info_from_multi_unit_listing(soup, outfile):
    #print("in get info from multi family listing")
    addr = get_address_string(soup)

    pricing_grid_items = soup.find_all("div", class_=PRICING_GRID_ITEM)
    for item in pricing_grid_items:
        classes = item.parent["class"]

        # This excludes not available listings and other listings that aren't shown to the user.
        if 'active' not in classes:
            continue
 
        data_lis = item.find_all("li", attrs={"data-beds" : re.compile(r'.*') })
        
        # Ah ha! This is one of those pages with just a price range
        if len(data_lis) == 0:
            save_less_precise_info_from_multi_unit_listing(soup, addr, outfile)
            return

        BEDS_ATTR = "data-beds"
        BATHS_ATTR = "data-baths"
        for i in range(len(data_lis)):
            ## print("i: ", i)
            li = data_lis[i]
            # The number of beds and baths are attributes of the <li>
            beds = li[BEDS_ATTR]
            baths = li[BATHS_ATTR]

            #Get price
            price_column = li.find("div", class_="pricingColumn")
            price_spans = price_column.find_all("span")
            assert len(price_spans) == 2, "Expected two spans in price column"
            price = price_spans[1].text.strip()

            
            # Get square footage
            sqft_column = li.find("div", class_="sqftColumn")
            sqft_text = sqft_column.text
            sqft_list = map(lambda s: s.replace(",", ""), sqft_text.split())
            sqft_list = [s for s in sqft_list if s.isdigit()]
            sqft = -1
            assert len(sqft_list) == 1, "UNEXPECTED square footage: " + sqft_text
            sqft = sqft_list[0]
            printstr = PRINT_STR.format(addr=addr, rent=price, beds=beds, baths=baths, sqft=sqft)
            outfile.write(printstr)

def get_info_from_listing(driver, apartment_outfile, location_outfile):
    #print("in get_info_from_listing")
    soup = BeautifulSoup(driver.page_source)
    url = driver.current_url
    save_per_location_info(soup, url, location_outfile)
    if is_single_unit_listing(soup):
        try:
            save_info_from_single_unit_listing(soup, apartment_outfile)
        except Exception as e:
            print("Could not extract info from single-unit listing. Got Exception: ", e)
    else:
        try:
            save_info_from_multi_unit_listing(soup, apartment_outfile)
        except Exception as e:
            print("Could not extract info from multi-unit listing. Got Exception: ", e)

# %%
m = re.match(r'(\d+)(?:[\-\.]\d+)?', '45')
m.groups()[0]
# Out:
# '45'

# %%
apts_outfile = open("/tmp/test.csv" , "w")
addr = get_address_string(soup)

save_info_from_single_unit_listing(soup=soup, outfile=apts_outfile)

apts_outfile.close()

# %%
import importlib
apts = importlib.import_module("ipynb.fs.full.scraping_apartments-dot-com")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[19], line 2
#       1 import importlib
# ----> 2 apts = importlib.import_module("ipynb.fs.full.scraping_apartments-dot-com")
#
# File /usr/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:848, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:219, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Projects/Data_Science/Apt_Prices/scraping_apartments-dot-com.ipynb:30
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 9,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "from selenium import webdriver\n",
#      10     "from selenium.webdriver.common.keys import Keys\n",
#      11     "from selenium.webdriver.common.by import By\n",
#      12     "from selenium.webdriver.chrome.options import Options\n",
#      13     "from fake_useragent import UserAgent\n",
#      14     "import re\n",
#      15     "from bs4 import BeautifulSoup\n",
#      16     "\n",
#      17     "import pandas as pd\n",
#      18     "import numpy as np"
#      19    ]
#      20   },
#      21   {
#      22    "cell_type": "markdown",
#      23    "metadata": {},
#      24    "source": [
#      25     "You're going to need one more function to tell if we should keep clicking next page.\n",
#      26     "\n",
#      27     "Look at all the li -> a's in the nav bar at the botton. Find the next to last one (meaning the last number before the right arrow). If its title contains \"Next page\", you're done clicking. Otherwise, keep clicking."
#      28    ]
#      29   },
# ---> 30   {
#      31    "cell_type": "code",
#      32    "execution_count": 10,
#      33    "metadata": {},
#      34    "outputs": [
#      35     {
#      36      "name": "stderr",
#      37      "output_type": "stream",
#      38      "text": [
#      39       "/tmp/ipykernel_21121/3547808522.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object\n",
#      40       "  driver = webdriver.Chrome('/home/bryce/Downloads/chromedriver', options=opts)\n"
#      41      ]
#      42     }
#      43    ],
#      44    "source": [
#      45     "opts = Options()\n",
#      46     "ua = UserAgent()\n",
#      47     "user_agent = ua.random\n",
#      48     "\n",
#      49     "opts.add_argument(\"user-agent=\" + user_agent)\n",
#      50     "driver = webdriver.Chrome('/home/bryce/Downloads/chromedriver', options=opts)\n",
#      51     "apt_url = \"https://www.apartments.com/charleston-sc/\"\n",
#      52     "#apt_url = \"https://www.apartments.com/2030-wildts-battery-blvd-johns-island-sc-unit-33847624/ks54vsb/\"\n",
#      53     "driver.get(apt_url)\n",
#      54     "driver.maximize_window()"
#      55    ]
#      56   },
#      57   {
#      58    "cell_type": "code",
#      59    "execution_count": 11,
#      60    "metadata": {},
#      61    "outputs": [],
#      62    "source": [
#      63     "from random import randint\n",
#      64     "from time import sleep\n",
#      65     "\n",
#      66     "def click_on_element(driver, element):\n",
#      67     "    sleep(randint(1,4))\n",
#      68     "    actions = ActionChains(driver)\n",
#      69     "    actions.move_to_element(element)\n",
#      70     "    actions.move_by_offset(randint(2, 10), randint(2,10))\n",
#      71     "    actions.pause(2)\n",
#      72     "    actions.click()\n",
#      73     "    actions.perform()"
#      74    ]
#      75   },
#      76   {
#      77    "cell_type": "code",
#      78    "execution_count": 12,
#      79    "metadata": {},
#      80    "outputs": [],
#      81    "source": [
#      82     "# For each apartment, we will write its info in this format:\n",
#      83     "PRINT_STR = \"{addr};; ${rent};; {beds} bd;; {baths} ba;; {sqft} sq ft\\n\"\n",
#      84     "PRICING_GRID_ITEM = \"pricingGridItem\"\n",
#      85     "SCREEN_READER_ONLY = \"screenReaderOnly\"\n",
#      86     "\n",
#      87     "def get_address_string(soup):\n",
#      88     "    address_divs = soup.find_all(\"div\", class_=\"propertyAddressContainer\")\n",
#      89     "    if (len(address_divs) == 0) :\n",
#      90     "        print(\"COULD NOT FIND ADDRESS\")\n",
#      91     "        return \"UNKNOWN ADDRESS\"\n",
#      92     "    addr_string = \" \".join(address_divs[0].text.split())\n",
#      93     "\n",
#      94     "    # Some properties have a property name like \"The Meadows\". In these properties, the addr_string contains the street address.\n",
#      95     "    # For single houses and such, the property name is the street address, and the addr_string will be missing it.\n",
#      96     "    property_name_split = soup.find(\"h1\", class_=\"propertyName\").text.split()\n",
#      97     "    if len(property_name_split) == 0:\n",
#      98     "        print(\"WARNING: no property name found.\")\n",
#      99     "        return addr_string\n",
#     100     "    # If the property name starts with a number, we'll assume it's an address.\n",
#     101     "    if property_name_split[0].isdigit():\n",
#     102     "        street_address = \" \".join(property_name_split)\n",
#     103     "        addr_string = street_address + \", \" + addr_string\n",
#     104     "\n",
#     105     "    return addr_string\n",
#     106     "\n",
#     107     "def is_single_unit_listing(soup):\n",
#     108     "    # Does this page have a div of class \"pricingGridItem\"? If so, return false. If not, true\n",
#     109     "    pricing_grid_items = soup.find_all(\"div\", class_=PRICING_GRID_ITEM)\n",
#     110     "    if (pricing_grid_items):\n",
#     111     "        return False\n",
#     112     "    return True\n",
#     113     "\n",
#     114     "def save_info_from_single_unit_listing(soup, outfile):\n",
#     115     "    address = get_address_string(soup)\n",
#     116     "    rent_details = soup.find_all(\"p\", class_=\"rentInfoDetail\")\n",
#     117     "    printstr = address + \";; \" + \";; \".join(map(lambda rd : rd.string, rent_details)) + \"\\n\"\n",
#     118     "    outfile.write(printstr)\n",
#     119     "\n",
#     120     "\"\"\" Some multi-unit listings have an exact price row for every\n",
#     121     "unit that's available. Otherse just have a price range for each floor plan.\n",
#     122     "This function handles the latter case.\n",
#     123     "We'll just save the price range as the price. When doing data analysis, we can\n",
#     124     "decide how to handle these cases.\"\"\"\n",
#     125     "def save_less_precise_info_from_multi_unit_listing(soup, address, outfile):\n",
#     126     "    pricing_grid_items = soup.find_all(\"div\", class_=PRICING_GRID_ITEM)\n",
#     127     "    for item in pricing_grid_items:\n",
#     128     "        classes = item.parent[\"class\"]\n",
#     129     "        if 'active' not in classes:\n",
#     130     "            continue\n",
#     131     "        rent_range = item.find(\"span\", class_=\"rentLabel\").text.strip()\n",
#     132     "        ### print(\"rent range: \", rent_range)\n",
#     133     "        # The first detailsTextWrapper has the bed, bath, sq ft info\n",
#     134     "        other_info = item.find(class_=\"detailsTextWrapper\").text\n",
#     135     "        other_info = other_info.replace(\"bed\", \"bd\").replace(\"bath\", \"ba\")\n",
#     136     "        formatted_info = \";; \".join([w.strip() for w in other_info.split(\",\")])\n",
#     137     "        println = \"{address};; {rent_range};; {bd_ba_sqft}\\n\".format(address=address, rent_range=rent_range, bd_ba_sqft=formatted_info)\n",
#     138     "        outfile.write(println)\n",
#     139     "\n",
#     140     "\n",
#     141     "def save_info_from_multi_unit_listing(soup, outfile):\n",
#     142     "    #print(\"in get info from multi family listing\")\n",
#     143     "    addr = get_address_string(soup)\n",
#     144     "\n",
#     145     "    pricing_grid_items = soup.find_all(\"div\", class_=PRICING_GRID_ITEM)\n",
#     146     "    for item in pricing_grid_items:\n",
#     147     "        classes = item.parent[\"class\"]\n",
#     148     "\n",
#     149     "        # This excludes not available listings and other listings that aren't shown to the user.\n",
#     150     "        if 'active' not in classes:\n",
#     151     "            continue\n",
#     152     " \n",
#     153     "        data_lis = item.find_all(\"li\", attrs={\"data-beds\" : re.compile(r'.*') })\n",
#     154     "        \n",
#     155     "        # Ah ha! This is one of those pages with just a price range\n",
#     156     "        if len(data_lis) == 0:\n",
#     157     "            save_less_precise_info_from_multi_unit_listing(soup, addr, outfile)\n",
#     158     "            return\n",
#     159     "\n",
#     160     "        BEDS_ATTR = \"data-beds\"\n",
#     161     "        BATHS_ATTR = \"data-baths\"\n",
#     162     "        for i in range(len(data_lis)):\n",
#     163     "            ## print(\"i: \", i)\n",
#     164     "            li = data_lis[i]\n",
#     165     "            # The number of beds and baths are attributes of the <li>\n",
#     166     "            beds = li[BEDS_ATTR]\n",
#     167     "            baths = li[BATHS_ATTR]\n",
#     168     "\n",
#     169     "            #Get price\n",
#     170     "            price_column = li.find(\"div\", class_=\"pricingColumn\")\n",
#     171     "            price_spans = price_column.find_all(\"span\")\n",
#     172     "            assert len(price_spans) == 2, \"Expected two spans in price column\"\n",
#     173     "            price = price_spans[1].text.strip()\n",
#     174     "\n",
#     175     "            \n",
#     176     "            # Get square footage\n",
#     177     "            sqft_column = li.find(\"div\", class_=\"sqftColumn\")\n",
#     178     "            sqft_text = sqft_column.text\n",
#     179     "            sqft_list = map(lambda s: s.replace(\",\", \"\"), sqft_text.split())\n",
#     180     "            sqft_list = [s for s in sqft_list if s.isdigit()]\n",
#     181     "            sqft = -1\n",
#     182     "            assert len(sqft_list) == 1, \"UNEXPECTED square footage: \" + sqft_text\n",
#     183     "            sqft = sqft_list[0]\n",
#     184     "            printstr = PRINT_STR.format(addr=addr, rent=price, beds=beds, baths=baths, sqft=sqft)\n",
#     185     "            outfile.write(printstr)\n",
#     186     "\n",
#     187     "def get_info_from_listing(driver, apartment_outfile, location_outfile):\n",
#     188     "    #print(\"in get_info_from_listing\")\n",
#     189     "    soup = BeautifulSoup(driver.page_source)\n",
#     190     "    url = driver.current_url\n",
#     191     "    save_per_location_info(soup, url, location_outfile)\n",
#     192     "    if is_single_unit_listing(soup):\n",
#     193     "        try:\n",
#     194     "            save_info_from_single_unit_listing(soup, apartment_outfile)\n",
#     195     "        except Exception as e:\n",
#     196     "            print(\"Could not extract info from single-unit listing. Got Exception: \", e)\n",
#     197     "    else:\n",
#     198     "        try:\n",
#     199     "            save_info_from_multi_unit_listing(soup, apartment_outfile)\n",
#     200     "        except Exception as e:\n",
#     201     "            print(\"Could not extract info from multi-unit listing. Got Exception: \", e)\n",
#     202     "\n",
#     203     "   \n",
#     204     "\n"
#     205    ]
#     206   },
#     207   {
#     208    "cell_type": "code",
#     209    "execution_count": 7,
#     210    "metadata": {},
#     211    "outputs": [],
#     212    "source": [
#     213     "SEMICOLON_REPLACEMENT = ',,,'\n",
#     214     "NEWLINE_REPLACEMENT = '   '\n",
#     215     "def replace_semicolons(text):\n",
#     216     "    return text.replace(';', SEMICOLON_REPLACEMENT)\n",
#     217     "\n",
#     218     "def add_semicolons_back(text):\n",
#     219     "    return text.replace(SEMICOLON_REPLACEMENT, ';')\n",
#     220     "\n",
#     221     "def replace_newlines(text):\n",
#     222     "    return text.replace('\\n', NEWLINE_REPLACEMENT)\n",
#     223     "\n",
#     224     "def add_newlines_back(text):\n",
#     225     "    return text.replae(NEWLINE_REPLACEMENT, '\\n')\n",
#     226     "\n",
#     227     "def save_per_location_info(soup, url, outfile):\n",
#     228     "    address = get_address_string(soup)\n",
#     229     "    address_without_semis = replace_semicolons(address)\n",
#     230     "    if (address != address_without_semis):\n",
#     231     "        print(\"WARNING, address \" + address + \" has semicolons, for url: \", url)\n",
#     232     "    description_section = soup.find(\"section\", class_=\"descriptionSection\")\n",
#     233     "    ps = description_section.find_all(\"p\")\n",
#     234     "    p1 = ps[0]\n",
#     235     "    if len(p1.attrs) > 0:\n",
#     236     "        print(\"WARNING, first <p> of description section has attrs for url: \", url)\n",
#     237     "    blurb = p1.text\n",
#     238     "    if len(blurb) == 0:\n",
#     239     "        print(\"WARNING, this page's blurb was length 0, for url \", url)\n",
#     240     "    blurb = replace_newlines(replace_semicolons(blurb))\n",
#     241     "    saveline = \"{address}; {url}; {blurb}\\n\".format(address=address_without_semis, url=url, blurb=blurb)\n",
#     242     "    outfile.write(saveline)\n",
#     243     "\n",
#     244     "    "
#     245    ]
#     246   },
#     247   {
#     248    "cell_type": "code",
#     249    "execution_count": 5,
#     250    "metadata": {},
#     251    "outputs": [
#     252     {
#     253      "ename": "NameError",
#     254      "evalue": "name 'driver' is not defined",
#     255      "output_type": "error",
#     256      "traceback": [
#     257       "\u001b---------------------------------------------------------------------------\u001b",
#     258       "\u001bNameError\u001b                                 Traceback (most recent call last)",
#     259       "Cell \u001bIn[5], line 3\u001b\n\u001b      1\u001b \u001bfrom\u001b \u001bbs4\u001b \u001bimport\u001b BeautifulSoup\n\u001b----> 3\u001b soup \u001b=\u001b BeautifulSoup(\u001bdriver\u001b\u001b.\u001bpage_source)\n\u001b      4\u001b \u001bprint\u001b(get_address_string(soup))\n",
#     260       "\u001bNameError\u001b: name 'driver' is not defined"
#     261      ]
#     262     }
#     263    ],
#     264    "source": [
#     265     "from bs4 import BeautifulSoup\n",
#     266     "\n",
#     267     "soup = BeautifulSoup(driver.page_source)\n",
#     268     "print(get_address_string(soup))\n"
#     269    ]
#     270   },
#     271   {
#     272    "cell_type": "code",
#     273    "execution_count": 13,
#     274    "metadata": {},
#     275    "outputs": [],
#     276    "source": [
#     277     "from selenium.webdriver.common.action_chains import ActionChains\n",
#     278     "from time import sleep\n",
#     279     "from random import randint\n",
#     280     "\n",
#     281     "def is_page_last(driver):\n",
#     282     "    page_range = driver.find_element(By.CLASS_NAME, \"pageRange\")\n",
#     283     "    page_range_text = page_range.text\n",
#     284     "    numbers = [int(w) for w in page_range_text.split() if w.isdigit()]\n",
#     285     "    assert len(numbers) == 2, \"We expect the page range to have two numbers in it, but apparently it doesn't: \" + page_range_text\n",
#     286     "    return numbers[0] == numbers[1]\n",
#     287     "\n",
#     288     "def click_to_next_page(driver):\n",
#     289     "    next_page_link = driver.find_element(By.CSS_SELECTOR, \"a.next\")\n",
#     290     "    sleep(randint(3,5))\n",
#     291     "    actions = ActionChains(driver)\n",
#     292     "    actions.move_to_element_with_offset(next_page_link, randint(1,10), randint(1,10))\n",
#     293     "    actions.pause(randint(1,3))\n",
#     294     "    actions.click()\n",
#     295     "    actions.perform()\n",
#     296     "\n",
#     297     "#click_to_next_page(driver)\n",
#     298     "    "
#     299    ]
#     300   },
#     301   {
#     302    "cell_type": "code",
#     303    "execution_count": 14,
#     304    "metadata": {},
#     305    "outputs": [],
#     306    "source": [
#     307     "import random\n",
#     308     "\n",
#     309     "def save_all_results_from_page(driver, apts_outfile, addr_outfile):\n",
#     310     "    apts_outfile.write(\"\\n\\n\")\n",
#     311     "    sleep(random.randint(5,9))\n",
#     312     "    count = 0\n",
#     313     "    #count = 23\n",
#     314     "    while True:\n",
#     315     "        links = driver.find_elements(By.CSS_SELECTOR, \"div.item.active.us\")\n",
#     316     "        if count >= len(links):\n",
#     317     "            print(\"count: \", count)\n",
#     318     "            print(\"number of links: \", len(links))\n",
#     319     "            break\n",
#     320     "        link = links[count]\n",
#     321     "        click_on_element(driver, link)\n",
#     322     "        sleep(random.random() + randint(1,2))\n",
#     323     "        get_info_from_listing(driver, apts_outfile, addr_outfile)\n",
#     324     "        print(\"Saved \" + str(count + 1) + \"'th result.\")\n",
#     325     "        driver.back()\n",
#     326     "        sleep(random.random() + randint(1,2))\n",
#     327     "        count += 1\n",
#     328     "    "
#     329    ]
#     330   },
#     331   {
#     332    "cell_type": "code",
#     333    "execution_count": 15,
#     334    "metadata": {},
#     335    "outputs": [
#     336     {
#     337      "name": "stdout",
#     338      "output_type": "stream",
#     339      "text": [
#     340       "Saved 1'th result.\n",
#     341       "Saved 2'th result.\n",
#     342       "Saved 3'th result.\n",
#     343       "Saved 4'th result.\n",
#     344       "Saved 5'th result.\n",
#     345       "Saved 6'th result.\n",
#     346       "Saved 7'th result.\n",
#     347       "Saved 8'th result.\n",
#     348       "Saved 9'th result.\n",
#     349       "Saved 10'th result.\n",
#     350       "Saved 11'th result.\n",
#     351       "Saved 12'th result.\n",
#     352       "Saved 13'th result.\n",
#     353       "Saved 14'th result.\n",
#     354       "Saved 15'th result.\n",
#     355       "Saved 16'th result.\n",
#     356       "Saved 17'th result.\n",
#     357       "Saved 18'th result.\n",
#     358       "Saved 19'th result.\n",
#     359       "Saved 20'th result.\n",
#     360       "Saved 21'th result.\n",
#     361       "Saved 22'th result.\n",
#     362       "Saved 23'th result.\n",
#     363       "Saved 24'th result.\n",
#     364       "Saved 25'th result.\n",
#     365       "count:  25\n",
#     366       "number of links:  25\n"
#     367      ]
#     368     }
#     369    ],
#     370    "source": [
#     371     "apt_outfile = open(\"/tmp/apt_results.csv\", \"w\")\n",
#     372     "addr_outfile = open(\"/tmp/addr_results.csv\", \"w\")\n",
#     373     "save_all_results_from_page(driver, apt_outfile, addr_outfile)\n",
#     374     "apt_outfile.close()\n",
#     375     "addr_outfile.close()"
#     376    ]
#     377   },
#     378   {
#     379    "cell_type": "code",
#     380    "execution_count": 7,
#     381    "metadata": {},
#     382    "outputs": [],
#     383    "source": [
#     384     "def save_all_results(driver, outfile):\n",
#     385     "    page = 1\n",
#     386     "    while True:\n",
#     387     "        print(\"About to save results from page \", page)\n",
#     388     "        save_all_results_from_page(driver, outfile)\n",
#     389     "        print(\"Finished saving page \", page)\n",
#     390     "        if is_page_last(driver):\n",
#     391     "            print(\"It's the last page!\")\n",
#     392     "            break\n",
#     393     "        print(\"Clicking to next page...\")\n",
#     394     "        click_to_next_page(driver)\n",
#     395     "        page += 1\n",
#     396     "            \n"
#     397    ]
#     398   },
#     399   {
#     400    "cell_type": "code",
#     401    "execution_count": 11,
#     402    "metadata": {},
#     403    "outputs": [
#     404     {
#     405      "name": "stdout",
#     406      "output_type": "stream",
#     407      "text": [
#     408       "About to save results from page  1\n",
#     409       "Saved 1'th result.\n",
#     410       "Saved 2'th result.\n",
#     411       "Saved 3'th result.\n",
#     412       "Saved 4'th result.\n",
#     413       "Saved 5'th result.\n",
#     414       "Saved 6'th result.\n",
#     415       "Saved 7'th result.\n",
#     416       "Saved 8'th result.\n",
#     417       "Saved 9'th result.\n",
#     418       "Saved 10'th result.\n",
#     419       "Saved 11'th result.\n",
#     420       "Saved 12'th result.\n",
#     421       "Saved 13'th result.\n",
#     422       "Saved 14'th result.\n",
#     423       "Saved 15'th result.\n",
#     424       "Saved 16'th result.\n",
#     425       "Saved 17'th result.\n",
#     426       "Saved 18'th result.\n",
#     427       "Saved 19'th result.\n",
#     428       "Saved 20'th result.\n",
#     429       "Saved 21'th result.\n",
#     430       "Saved 22'th result.\n",
#     431       "Saved 23'th result.\n",
#     432       "Saved 24'th result.\n",
#     433       "Saved 25'th result.\n",
#     434       "count:  25\n",
#     435       "number of links:  25\n",
#     436       "Finished saving page  1\n",
#     437       "Clicking to next page...\n",
#     438       "About to save results from page  2\n",
#     439       "Saved 1'th result.\n",
#     440       "Saved 2'th result.\n",
#     441       "Saved 3'th result.\n",
#     442       "Saved 4'th result.\n",
#     443       "Saved 5'th result.\n",
#     444       "Saved 6'th result.\n",
#     445       "Saved 7'th result.\n",
#     446       "Saved 8'th result.\n",
#     447       "Saved 9'th result.\n",
#     448       "Saved 10'th result.\n",
#     449       "Saved 11'th result.\n",
#     450       "Saved 12'th result.\n",
#     451       "Saved 13'th result.\n",
#     452       "Saved 14'th result.\n",
#     453       "Saved 15'th result.\n",
#     454       "Saved 16'th result.\n",
#     455       "Saved 17'th result.\n",
#     456       "Saved 18'th result.\n",
#     457       "Saved 19'th result.\n",
#     458       "Saved 20'th result.\n",
#     459       "Saved 21'th result.\n",
#     460       "Saved 22'th result.\n",
#     461       "Saved 23'th result.\n",
#     462       "Saved 24'th result.\n",
#     463       "Saved 25'th result.\n",
#     464       "count:  25\n",
#     465       "number of links:  25\n",
#     466       "Finished saving page  2\n",
#     467       "Clicking to next page...\n",
#     468       "About to save results from page  3\n",
#     469       "Saved 1'th result.\n",
#     470       "Saved 2'th result.\n",
#     471       "Saved 3'th result.\n",
#     472       "Saved 4'th result.\n",
#     473       "Saved 5'th result.\n",
#     474       "Saved 6'th result.\n",
#     475       "Saved 7'th result.\n",
#     476       "Could not extract info from multi-unit listing. Got Exception:  UNEXPECTED square footage: \n",
#     477       "square feet \n",
#     478       "\n",
#     479       "\n",
#     480       "Saved 8'th result.\n",
#     481       "Saved 9'th result.\n",
#     482       "Saved 10'th result.\n",
#     483       "Saved 11'th result.\n",
#     484       "Saved 12'th result.\n",
#     485       "Saved 13'th result.\n",
#     486       "Saved 14'th result.\n",
#     487       "Saved 15'th result.\n",
#     488       "Saved 16'th result.\n",
#     489       "Saved 17'th result.\n",
#     490       "Saved 18'th result.\n",
#     491       "Saved 19'th result.\n",
#     492       "Saved 20'th result.\n",
#     493       "Saved 21'th result.\n",
#     494       "Saved 22'th result.\n",
#     495       "Saved 23'th result.\n",
#     496       "Saved 24'th result.\n",
#     497       "Saved 25'th result.\n",
#     498       "count:  25\n",
#     499       "number of links:  25\n",
#     500       "Finished saving page  3\n",
#     501       "Clicking to next page...\n",
#     502       "About to save results from page  4\n",
#     503       "Saved 1'th result.\n",
#     504       "Saved 2'th result.\n",
#     505       "Saved 3'th result.\n",
#     506       "Saved 4'th result.\n",
#     507       "Saved 5'th result.\n",
#     508       "Saved 6'th result.\n",
#     509       "Saved 7'th result.\n",
#     510       "Saved 8'th result.\n",
#     511       "Saved 9'th result.\n",
#     512       "Saved 10'th result.\n",
#     513       "Saved 11'th result.\n",
#     514       "Saved 12'th result.\n",
#     515       "Saved 13'th result.\n",
#     516       "Saved 14'th result.\n",
#     517       "Saved 15'th result.\n",
#     518       "Saved 16'th result.\n",
#     519       "Saved 17'th result.\n",
#     520       "Saved 18'th result.\n",
#     521       "Saved 19'th result.\n",
#     522       "Saved 20'th result.\n",
#     523       "Saved 21'th result.\n",
#     524       "Saved 22'th result.\n",
#     525       "Saved 23'th result.\n",
#     526       "Saved 24'th result.\n",
#     527       "Saved 25'th result.\n",
#     528       "count:  25\n",
#     529       "number of links:  25\n",
#     530       "Finished saving page  4\n",
#     531       "Clicking to next page...\n",
#     532       "About to save results from page  5\n",
#     533       "Saved 1'th result.\n",
#     534       "Saved 2'th result.\n",
#     535       "Saved 3'th result.\n",
#     536       "Saved 4'th result.\n",
#     537       "Saved 5'th result.\n",
#     538       "Saved 6'th result.\n",
#     539       "Saved 7'th result.\n",
#     540       "Saved 8'th result.\n",
#     541       "Saved 9'th result.\n",
#     542       "Saved 10'th result.\n",
#     543       "Saved 11'th result.\n",
#     544       "Could not extract info from multi-unit listing. Got Exception:  Expected two spans in price column\n",
#     545       "Saved 12'th result.\n",
#     546       "Saved 13'th result.\n",
#     547       "Saved 14'th result.\n",
#     548       "Saved 15'th result.\n",
#     549       "Saved 16'th result.\n",
#     550       "Saved 17'th result.\n",
#     551       "Saved 18'th result.\n",
#     552       "Saved 19'th result.\n",
#     553       "Saved 20'th result.\n",
#     554       "Saved 21'th result.\n",
#     555       "Saved 22'th result.\n",
#     556       "Saved 23'th result.\n",
#     557       "Saved 24'th result.\n",
#     558       "Saved 25'th result.\n",
#     559       "count:  25\n",
#     560       "number of links:  25\n",
#     561       "Finished saving page  5\n",
#     562       "Clicking to next page...\n",
#     563       "About to save results from page  6\n",
#     564       "Saved 1'th result.\n",
#     565       "Saved 2'th result.\n",
#     566       "Saved 3'th result.\n",
#     567       "Saved 4'th result.\n",
#     568       "Saved 5'th result.\n",
#     569       "Saved 6'th result.\n",
#     570       "Saved 7'th result.\n",
#     571       "Saved 8'th result.\n",
#     572       "Saved 9'th result.\n",
#     573       "Saved 10'th result.\n",
#     574       "Saved 11'th result.\n",
#     575       "Saved 12'th result.\n",
#     576       "Saved 13'th result.\n",
#     577       "Saved 14'th result.\n",
#     578       "Saved 15'th result.\n",
#     579       "Saved 16'th result.\n",
#     580       "Saved 17'th result.\n",
#     581       "Saved 18'th result.\n",
#     582       "Saved 19'th result.\n",
#     583       "Saved 20'th result.\n",
#     584       "Saved 21'th result.\n",
#     585       "Saved 22'th result.\n",
#     586       "Saved 23'th result.\n",
#     587       "Saved 24'th result.\n",
#     588       "Saved 25'th result.\n",
#     589       "count:  25\n",
#     590       "number of links:  25\n",
#     591       "Finished saving page  6\n",
#     592       "Clicking to next page...\n",
#     593       "About to save results from page  7\n",
#     594       "Saved 1'th result.\n",
#     595       "Saved 2'th result.\n",
#     596       "Saved 3'th result.\n",
#     597       "Saved 4'th result.\n",
#     598       "Saved 5'th result.\n",
#     599       "Saved 6'th result.\n",
#     600       "Saved 7'th result.\n",
#     601       "Saved 8'th result.\n",
#     602       "Saved 9'th result.\n",
#     603       "Saved 10'th result.\n",
#     604       "Saved 11'th result.\n",
#     605       "Saved 12'th result.\n",
#     606       "Saved 13'th result.\n",
#     607       "Saved 14'th result.\n",
#     608       "Saved 15'th result.\n",
#     609       "Saved 16'th result.\n",
#     610       "Saved 17'th result.\n",
#     611       "Saved 18'th result.\n",
#     612       "Saved 19'th result.\n",
#     613       "Saved 20'th result.\n",
#     614       "Saved 21'th result.\n",
#     615       "Saved 22'th result.\n",
#     616       "Saved 23'th result.\n",
#     617       "Saved 24'th result.\n",
#     618       "Saved 25'th result.\n",
#     619       "count:  25\n",
#     620       "number of links:  25\n",
#     621       "Finished saving page  7\n",
#     622       "Clicking to next page...\n",
#     623       "About to save results from page  8\n",
#     624       "Saved 1'th result.\n",
#     625       "COULD NOT FIND ADDRESS\n",
#     626       "Saved 2'th result.\n",
#     627       "Saved 3'th result.\n",
#     628       "Saved 4'th result.\n",
#     629       "COULD NOT FIND ADDRESS\n",
#     630       "Saved 5'th result.\n",
#     631       "Could not extract info from single-unit listing. Got Exception:  sequence item 3: expected str instance, NoneType found\n",
#     632       "Saved 6'th result.\n",
#     633       "Could not extract info from single-unit listing. Got Exception:  sequence item 3: expected str instance, NoneType found\n",
#     634       "Saved 7'th result.\n",
#     635       "Saved 8'th result.\n",
#     636       "Could not extract info from single-unit listing. Got Exception:  sequence item 3: expected str instance, NoneType found\n",
#     637       "Saved 9'th result.\n",
#     638       "Could not extract info from single-unit listing. Got Exception:  sequence item 3: expected str instance, NoneType found\n",
#     639       "Saved 10'th result.\n",
#     640       "Saved 11'th result.\n",
#     641       "Saved 12'th result.\n",
#     642       "Saved 13'th result.\n",
#     643       "Saved 14'th result.\n",
#     644       "Saved 15'th result.\n",
#     645       "Saved 16'th result.\n",
#     646       "Could not extract info from single-unit listing. Got Exception:  sequence item 3: expected str instance, NoneType found\n",
#     647       "Saved 17'th result.\n",
#     648       "Saved 18'th result.\n",
#     649       "Could not extract info from single-unit listing. Got Exception:  sequence item 3: expected str instance, NoneType found\n",
#     650       "Saved 19'th result.\n",
#     651       "Saved 20'th result.\n",
#     652       "Saved 21'th result.\n",
#     653       "Could not extract info from single-unit listing. Got Exception:  sequence item 3: expected str instance, NoneType found\n",
#     654       "Saved 22'th result.\n",
#     655       "Saved 23'th result.\n",
#     656       "Saved 24'th result.\n",
#     657       "Saved 25'th result.\n",
#     658       "count:  25\n",
#     659       "number of links:  25\n",
#     660       "Finished saving page  8\n",
#     661       "Clicking to next page...\n",
#     662       "About to save results from page  9\n",
#     663       "Saved 1'th result.\n",
#     664       "Saved 2'th result.\n",
#     665       "Could not extract info from single-unit listing. Got Exception:  sequence item 3: expected str instance, NoneType found\n",
#     666       "Saved 3'th result.\n",
#     667       "Saved 4'th result.\n",
#     668       "Saved 5'th result.\n",
#     669       "Saved 6'th result.\n",
#     670       "Saved 7'th result.\n",
#     671       "Saved 8'th result.\n",
#     672       "Saved 9'th result.\n",
#     673       "Saved 10'th result.\n",
#     674       "Saved 11'th result.\n",
#     675       "Could not extract info from single-unit listing. Got Exception:  sequence item 3: expected str instance, NoneType found\n",
#     676       "Saved 12'th result.\n",
#     677       "Saved 13'th result.\n",
#     678       "Saved 14'th result.\n",
#     679       "Saved 15'th result.\n",
#     680       "Saved 16'th result.\n",
#     681       "Saved 17'th result.\n",
#     682       "Saved 18'th result.\n",
#     683       "Saved 19'th result.\n",
#     684       "Saved 20'th result.\n",
#     685       "Saved 21'th result.\n",
#     686       "Saved 22'th result.\n",
#     687       "Saved 23'th result.\n",
#     688       "Saved 24'th result.\n",
#     689       "Saved 25'th result.\n",
#     690       "count:  25\n",
#     691       "number of links:  25\n",
#     692       "Finished saving page  9\n",
#     693       "Clicking to next page...\n",
#     694       "About to save results from page  10\n",
#     695       "Saved 1'th result.\n",
#     696       "Saved 2'th result.\n",
#     697       "Saved 3'th result.\n",
#     698       "Saved 4'th result.\n",
#     699       "Saved 5'th result.\n",
#     700       "Saved 6'th result.\n",
#     701       "Saved 7'th result.\n",
#     702       "Saved 8'th result.\n",
#     703       "Saved 9'th result.\n",
#     704       "Saved 10'th result.\n",
#     705       "Saved 11'th result.\n",
#     706       "Saved 12'th result.\n",
#     707       "Saved 13'th result.\n",
#     708       "Saved 14'th result.\n",
#     709       "Saved 15'th result.\n",
#     710       "Saved 16'th result.\n",
#     711       "Saved 17'th result.\n",
#     712       "Saved 18'th result.\n",
#     713       "Saved 19'th result.\n",
#     714       "Saved 20'th result.\n",
#     715       "Saved 21'th result.\n",
#     716       "Saved 22'th result.\n",
#     717       "Saved 23'th result.\n",
#     718       "Saved 24'th result.\n",
#     719       "Saved 25'th result.\n",
#     720       "count:  25\n",
#     721       "number of links:  25\n",
#     722       "Finished saving page  10\n",
#     723       "Clicking to next page...\n",
#     724       "About to save results from page  11\n",
#     725       "Saved 1'th result.\n",
#     726       "Saved 2'th result.\n",
#     727       "Saved 3'th result.\n",
#     728       "Saved 4'th result.\n",
#     729       "Saved 5'th result.\n",
#     730       "Saved 6'th result.\n",
#     731       "Saved 7'th result.\n",
#     732       "Saved 8'th result.\n",
#     733       "Saved 9'th result.\n",
#     734       "Saved 10'th result.\n",
#     735       "Saved 11'th result.\n",
#     736       "Saved 12'th result.\n",
#     737       "Saved 13'th result.\n",
#     738       "Saved 14'th result.\n",
#     739       "Saved 15'th result.\n",
#     740       "Saved 16'th result.\n",
#     741       "Saved 17'th result.\n",
#     742       "Saved 18'th result.\n",
#     743       "Saved 19'th result.\n",
#     744       "Saved 20'th result.\n",
#     745       "Saved 21'th result.\n",
#     746       "Saved 22'th result.\n",
#     747       "Saved 23'th result.\n",
#     748       "Saved 24'th result.\n",
#     749       "Saved 25'th result.\n",
#     750       "count:  25\n",
#     751       "number of links:  25\n",
#     752       "Finished saving page  11\n",
#     753       "Clicking to next page...\n",
#     754       "About to save results from page  12\n",
#     755       "Saved 1'th result.\n",
#     756       "Saved 2'th result.\n",
#     757       "Saved 3'th result.\n",
#     758       "Saved 4'th result.\n",
#     759       "Saved 5'th result.\n",
#     760       "Saved 6'th result.\n",
#     761       "Saved 7'th result.\n",
#     762       "Saved 8'th result.\n",
#     763       "Saved 9'th result.\n",
#     764       "Saved 10'th result.\n",
#     765       "Saved 11'th result.\n",
#     766       "Saved 12'th result.\n",
#     767       "Saved 13'th result.\n",
#     768       "Saved 14'th result.\n",
#     769       "Saved 15'th result.\n",
#     770       "Saved 16'th result.\n",
#     771       "Saved 17'th result.\n",
#     772       "Saved 18'th result.\n",
#     773       "Saved 19'th result.\n",
#     774       "Saved 20'th result.\n",
#     775       "Saved 21'th result.\n",
#     776       "Saved 22'th result.\n",
#     777       "Saved 23'th result.\n",
#     778       "Saved 24'th result.\n",
#     779       "Saved 25'th result.\n",
#     780       "count:  25\n",
#     781       "number of links:  25\n",
#     782       "Finished saving page  12\n",
#     783       "Clicking to next page...\n",
#     784       "About to save results from page  13\n",
#     785       "Saved 1'th result.\n",
#     786       "Saved 2'th result.\n",
#     787       "Saved 3'th result.\n",
#     788       "Saved 4'th result.\n",
#     789       "Saved 5'th result.\n",
#     790       "Saved 6'th result.\n",
#     791       "Saved 7'th result.\n",
#     792       "Saved 8'th result.\n",
#     793       "Saved 9'th result.\n",
#     794       "Saved 10'th result.\n",
#     795       "Saved 11'th result.\n",
#     796       "Saved 12'th result.\n",
#     797       "Saved 13'th result.\n",
#     798       "Saved 14'th result.\n",
#     799       "Saved 15'th result.\n",
#     800       "Saved 16'th result.\n",
#     801       "Saved 17'th result.\n",
#     802       "Saved 18'th result.\n",
#     803       "Saved 19'th result.\n",
#     804       "Saved 20'th result.\n",
#     805       "Saved 21'th result.\n",
#     806       "Saved 22'th result.\n",
#     807       "Saved 23'th result.\n",
#     808       "Saved 24'th result.\n",
#     809       "Saved 25'th result.\n",
#     810       "count:  25\n",
#     811       "number of links:  25\n",
#     812       "Finished saving page  13\n",
#     813       "Clicking to next page...\n",
#     814       "About to save results from page  14\n",
#     815       "Saved 1'th result.\n",
#     816       "Saved 2'th result.\n",
#     817       "Saved 3'th result.\n",
#     818       "Saved 4'th result.\n",
#     819       "Saved 5'th result.\n",
#     820       "Saved 6'th result.\n",
#     821       "Saved 7'th result.\n",
#     822       "Saved 8'th result.\n",
#     823       "Saved 9'th result.\n",
#     824       "Saved 10'th result.\n",
#     825       "Saved 11'th result.\n",
#     826       "Saved 12'th result.\n",
#     827       "Saved 13'th result.\n",
#     828       "Saved 14'th result.\n",
#     829       "Saved 15'th result.\n",
#     830       "Saved 16'th result.\n",
#     831       "Saved 17'th result.\n",
#     832       "Saved 18'th result.\n",
#     833       "Saved 19'th result.\n",
#     834       "Saved 20'th result.\n",
#     835       "Saved 21'th result.\n",
#     836       "Saved 22'th result.\n",
#     837       "Saved 23'th result.\n",
#     838       "Saved 24'th result.\n",
#     839       "Saved 25'th result.\n",
#     840       "count:  25\n",
#     841       "number of links:  25\n",
#     842       "Finished saving page  14\n",
#     843       "Clicking to next page...\n",
#     844       "About to save results from page  15\n",
#     845       "Saved 1'th result.\n",
#     846       "Saved 2'th result.\n",
#     847       "Saved 3'th result.\n",
#     848       "Saved 4'th result.\n",
#     849       "Saved 5'th result.\n",
#     850       "Saved 6'th result.\n",
#     851       "Could not extract info from single-unit listing. Got Exception:  sequence item 3: expected str instance, NoneType found\n",
#     852       "Saved 7'th result.\n",
#     853       "Saved 8'th result.\n",
#     854       "Saved 9'th result.\n",
#     855       "Saved 10'th result.\n",
#     856       "Saved 11'th result.\n",
#     857       "Saved 12'th result.\n",
#     858       "Saved 13'th result.\n",
#     859       "Saved 14'th result.\n",
#     860       "Saved 15'th result.\n",
#     861       "Saved 16'th result.\n",
#     862       "Saved 17'th result.\n",
#     863       "Saved 18'th result.\n",
#     864       "Saved 19'th result.\n",
#     865       "Saved 20'th result.\n",
#     866       "Saved 21'th result.\n",
#     867       "Saved 22'th result.\n",
#     868       "Saved 23'th result.\n",
#     869       "Saved 24'th result.\n",
#     870       "Saved 25'th result.\n",
#     871       "count:  25\n",
#     872       "number of links:  25\n",
#     873       "Finished saving page  15\n",
#     874       "Clicking to next page...\n",
#     875       "About to save results from page  16\n",
#     876       "Saved 1'th result.\n",
#     877       "count:  1\n",
#     878       "number of links:  1\n",
#     879       "Finished saving page  16\n",
#     880       "It's the last page!\n"
#     881      ]
#     882     }
#     883    ],
#     884    "source": [
#     885     "outfile = open(\"/home/bryce/Projects/Data_Science/Apt_Prices/all-results.csv\", \"w\")\n",
#     886     "\n",
#     887     "save_all_results(driver, outfile)\n",
#     888     "outfile.close()"
#     889    ]
#     890   },
#     891   {
#     892    "cell_type": "code",
#     893    "execution_count": null,
#     894    "metadata": {},
#     895    "outputs": [],
#     896    "source": []
#     897   },
#     898   {
#     899    "cell_type": "code",
#     900    "execution_count": null,
#     901    "metadata": {},
#     902    "outputs": [],
#     903    "source": [
#     904     "outfile = open(\"/home/bryce/Projects/Data_Science/Apt_Prices/all-results.csv\", \"w\")\n",
#     905     "\n",
#     906     "save_all_results(driver, outfile)\n",
#     907     "outfile.close()"
#     908    ]
#     909   },
#     910   {
#     911    "cell_type": "code",
#     912    "execution_count": null,
#     913    "metadata": {},
#     914    "outputs": [],
#     915    "source": [
#     916     "out_file = open('/tmp/aptscom.csv', 'w')\n",
#     917     "print(\"hi\")\n",
#     918     "get_info_from_listing(driver, out_file)\n",
#     919     "print(\"bye\")\n",
#     920     "out_file.close()  "
#     921    ]
#     922   }
#     923  ],
#     924  "metadata": {
#     925   "kernelspec": {
#     926    "display_name": "Python 3.8.10 64-bit",
#     927    "language": "python",
#     928    "name": "python3"
#     929   },
#     930   "language_info": {
#     931    "codemirror_mode": {
#     932     "name": "ipython",
#     933     "version": 3
#     934    },
#     935    "file_extension": ".py",
#     936    "mimetype": "text/x-python",
#     937    "name": "python",
#     938    "nbconvert_exporter": "python",
#     939    "pygments_lexer": "ipython3",
#     940    "version": "3.8.10"
#     941   },
#     942   "orig_nbformat": 4,
#     943   "vscode": {
#     944    "interpreter": {
#     945     "hash": "916dbcbb3f70747c44a77c7bcd40155683ae19c65e1c03b4aa3499c5328201f1"
#     946    }
#     947   }
#     948  },
#     949  "nbformat": 4,
#     950  "nbformat_minor": 2
#     951 }
#
# File ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:455, in WebDriver.get(self, url)
#     451 def get(self, url: str) -> None:
#     452     """
#     453     Loads a web page in the current browser session.
#     454     """
# --> 455     self.execute(Command.GET, {"url": url})
#
# File ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: cannot determine loading status
# from target frame detached
#   (Session info: chrome=109.0.5414.74)
# Stacktrace:
# #0 0x55976d913303 <unknown>
# #1 0x55976d6e7bbd <unknown>
# #2 0x55976d6d2233 <unknown>
# #3 0x55976d6d0c77 <unknown>
# #4 0x55976d6d1408 <unknown>
# #5 0x55976d6dea1a <unknown>
# #6 0x55976d6df2d2 <unknown>
# #7 0x55976d6effd0 <unknown>
# #8 0x55976d6f434b <unknown>
# #9 0x55976d6d19c5 <unknown>
# #10 0x55976d6efbd2 <unknown>
# #11 0x55976d75caa0 <unknown>
# #12 0x55976d744753 <unknown>
# #13 0x55976d717a14 <unknown>
# #14 0x55976d718b7e <unknown>
# #15 0x55976d96232e <unknown>
# #16 0x55976d965c0e <unknown>
# #17 0x55976d948610 <unknown>
# #18 0x55976d966c23 <unknown>
# #19 0x55976d93a545 <unknown>
# #20 0x55976d9876a8 <unknown>
# #21 0x55976d987836 <unknown>
# #22 0x55976d9a2d13 <unknown>
# #23 0x7fd498254609 start_thread

# %%
ps = description_section.find_all("p")
p2 = ps[1]
p2.attrs 
len(p2.attrs)
# Out:
# 1

# %%
SEMICOLON_REPLACEMENT = ',,,'
def replace_semicolons(text):
    text = text.replace(';', SEMICOLON_REPLACEMENT)
    return text

def add_semicolons_back(text):
    text = text.replace(SEMICOLON_REPLACEMENT, ';')
    return text

# %%
a = 'a string;'
b = a.encode(encoding='ascii')
c = a.encode()

print(b)
print(c)
# Out:
# b'a string;'
# b'a string;'
